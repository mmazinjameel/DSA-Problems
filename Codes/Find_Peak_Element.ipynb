# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        
        hi = len(nums)-1
        lo = 0

        while(hi>lo):
            mid = (hi+lo)//2

            if nums[mid] > nums[mid+1]:
                hi = mid

            else:
                lo = mid+1

        return lo
